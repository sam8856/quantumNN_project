# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pennylane as qml

from sklearn.model_selection import train_test_split

# Direct classes included for easyness
from tensorflow.keras.utils import plot_model
from tensorflow.keras.backend import clear_session
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.backend import clear_session
from tensorflow.keras.models import Model, load_model, load_weights

# %%
# load data
np_data = np.load("data/dataRS.npy")

noise_output = np_data[:,-1].reshape(len(np_data),1)
input = np_data[:,:-1]

# split data
test_split = 0.33
x_train, x_test, y_train, y_test = train_test_split(input, noise_output, test_size=test_split, random_state=42)

# %% [markdown]
# ### Enter your tag as unique id for saving

# %%
tag = str("quantumAutoencoder2-18032023")

# %%
from qiskit import IBMQ
from qiskit_ibm_provider import IBMProvider 
provider = IBMQ.enable_account(token="be3f937e2d604f9b53d411ad48a467e6d5e9a199249317e1dc2c4eed5659a66ee10655e68b079eda2aeb4b165e59c5c11a9c3a2abb9d31367ae59897b5f54f60")
# Out:
# ---------------------------------------------------------------------------
# IBMQAccountError                          Traceback (most recent call last)
# Cell In[20], line 3
#       1 from qiskit import IBMQ
#       2 from qiskit_ibm_provider import IBMProvider
# ----> 3 provider = IBMQ.enable_account(token="be3f937e2d604f9b53d411ad48a467e6d5e9a199249317e1dc2c4eed5659a66ee10655e68b079eda2aeb4b165e59c5c11a9c3a2abb9d31367ae59897b5f54f60")
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit\providers\ibmq\ibmqfactory.py:93, in IBMQFactory.enable_account(self, token, url, hub, group, project, **kwargs)
#      91 # Check if an IBM Quantum Experience account is already in use.
#      92 if self._credentials:
# ---> 93     raise IBMQAccountError(
#      94         'An IBM Quantum Experience account is already in use for the session.')
#      96 # Check the version used by these credentials.
#      97 credentials = Credentials(token, url, **kwargs)
#
# IBMQAccountError: 'An IBM Quantum Experience account is already in use for the session.'

# %%
IBMQ.providers()
my_provider = IBMQ.get_provider()
my_provider.backends()
my_provider.get_backend('ibm_nairobi')
# Out:
# <IBMQBackend('ibm_nairobi') from IBMQ(hub='ibm-q', group='open', project='main')>

# %%
from pennylane import numpy as np
n_qubits = x_train.shape[1]
x_qubits = 3
compression = 3
dev = qml.device('qiskit.ibmq', wires=(n_qubits), provider=my_provider, backend='ibm_nairobi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 5
#       3 x_qubits = 3
#       4 compression = 3
# ----> 5 dev = qml.device('qiskit.ibmq', wires=(n_qubits+x_qubits), provider=my_provider, backend='ibm_nairobi')
#       6 # dev = qml.device("default.qubit", wires=(n_qubits+x_qubits))
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\pennylane\__init__.py:326, in device(name, *args, **kwargs)
#     320     raise DeviceError(
#     321         f"The {name} plugin requires PennyLane versions {plugin_device_class.pennylane_requires}, "
#     322         f"however PennyLane version {__version__} is installed."
#     323     )
#     325 # Construct the device
# --> 326 dev = plugin_device_class(*args, **options)
#     328 # Once the device is constructed, we set its custom expansion function if
#     329 # any custom decompositions were specified.
#     330 if custom_decomps is not None:
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\pennylane_qiskit\ibmq.py:74, in IBMQDevice.__init__(self, wires, provider, backend, shots, **kwargs)
#      71 # get a provider
#      72 p = provider or IBMQ.get_provider(hub=hub, group=group, project=project)
# ---> 74 super().__init__(wires=wires, provider=p, backend=backend, shots=shots, **kwargs)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\pennylane_qiskit\qiskit_device.py:173, in QiskitDevice.__init__(self, wires, provider, backend, shots, **kwargs)
#     171 b = self.backend
#     172 if len(self.wires) > int(b.configuration().n_qubits):
# --> 173     raise ValueError(
#     174         f"Backend '{backend}' supports maximum {b.configuration().n_qubits} wires"
#     175     )
#     177 # Initialize inner state
#     178 self.reset()
#
# ValueError: Backend 'ibm_nairobi' supports maximum 7 wires

# %%
# Encoder
ENC_weight_shapes = {"weight1": (n_qubits),
                 "weight2": (n_qubits-1),
                 "weight3": (n_qubits-1),
                 "weight4": (n_qubits-1),
                 "weight5": (n_qubits)}
nE_qcParams = n_qubits*2+3*(n_qubits-1)
print(f"Params in the quantum layer to train: {nE_qcParams}")



@qml.qnode(dev)
def encoder(inputs, weight1, weight2, weight3, weight4, weight5):
    
    qml.broadcast(qml.RY, wires=range(n_qubits), parameters=inputs, pattern="single")
    
    qml.broadcast(qml.RY, wires=range(n_qubits), parameters=weight1, pattern="single")
    qml.broadcast(qml.CRY, wires=range(n_qubits), parameters=weight2, pattern="chain")
    qml.broadcast(qml.CRY, wires=range(n_qubits), parameters=weight3, pattern="chain")
    qml.broadcast(qml.CRY, wires=range(n_qubits), parameters=weight4, pattern="chain")
    qml.broadcast(qml.RY, wires=range(n_qubits), parameters=weight5, pattern="single")
    
    qml.Hadamard(wires=5)
    qml.CSWAP(wires=[5,6,4])
    qml.CSWAP(wires=[5,7,3])
    qml.Hadamard(wires=5)
    return [qml.expval(qml.PauliZ(wires=0)), qml.expval(qml.PauliZ(wires=1)), qml.expval(qml.PauliZ(wires=2)), qml.expval(qml.PauliZ(wires=5))]
    # return qml.expval(qml.PauliZ(wires=5))

qEncoder = qml.qnn.KerasLayer(encoder, ENC_weight_shapes, output_dim=n_qubits)

# Visualize the quantum circuit
print(qml.draw(encoder)(x_train[0,:],np.random.rand(n_qubits), np.random.rand(n_qubits-1), np.random.rand(n_qubits-1), np.random.rand(n_qubits-1), np.random.rand(n_qubits)))
fig1, ax = qml.draw_mpl(encoder)(x_train[0,:],np.random.rand(n_qubits), np.random.rand(n_qubits-1), np.random.rand(n_qubits-1), np.random.rand(n_qubits-1), np.random.rand(n_qubits))
plt.show()
fig1.savefig("archive/Encoder-"+tag+".png")
fig1.savefig("archive/Encoder-"+tag+".pdf")
# Out:
# Params in the quantum layer to train: 22
# 0: ──RY(0.02)──RY(0.17)─╭●──────────────────╭●──────────────────╭●─────────RY(0.11)──────────
# 1: ──RY(0.50)──RY(0.06)─╰RY(0.59)─╭●────────╰RY(0.32)─╭●────────╰RY(0.77)─╭●─────────RY(0.12)
# 2: ──RY(0.09)──RY(0.58)───────────╰RY(0.82)─╭●────────╰RY(0.89)─╭●────────╰RY(0.20)─╭●───────
# 3: ──RY(1.00)──RY(0.02)─────────────────────╰RY(0.08)─╭●────────╰RY(0.04)─╭●────────╰RY(0.71)
# 4: ──RY(0.24)──RY(0.30)───────────────────────────────╰RY(0.17)───────────╰RY(0.63)──────────
# 5: ──H───────────────────────────────────────────────────────────────────────────────────────
# 6: ──────────────────────────────────────────────────────────────────────────────────────────
# 7: ──────────────────────────────────────────────────────────────────────────────────────────
#
# ─────────────────────────────────────┤  <Z>
# ─────────────────────────────────────┤  <Z>
# ───RY(0.75)──────────────────────────┤  <Z>
# ──╭●─────────RY(0.30)───────╭SWAP────┤
# ──╰RY(0.88)──RY(0.23)─╭SWAP─│────────┤
# ──────────────────────├●────├●─────H─┤  <Z>
# ──────────────────────╰SWAP─│────────┤
# ────────────────────────────╰SWAP────┤

# %%
encoderQ2 = load_model("archive/")

# %%
#Training
#['mean_squared_error', 'mean_absolute_error','mean_squared_logarithmic_error', 'mean_absolute_percentage_error']

inputLayer = Input(shape=(x_train.shape[1],))
encoded = qEncoder(inputLayer)
# Encoder
encoderModel = Model(inputLayer, encoded)
def cost(y_true, y_pred):
    y_pred = y_pred[:,3]
    squared_difference = tf.square(y_true - y_pred)
    return tf.reduce_mean(squared_difference, axis=-1)
def scheduler(epoch, lr):
    if epoch < 8:
        return lr
    else:
        return lr* tf.math.exp(-0.1)
LearningRateScheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)
EarlyStopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="auto", min_delta=0.001, patience=20)

optRMS = tf.keras.optimizers.RMSprop(learning_rate=0.05)

encoderModel.compile(optimizer = optRMS, loss=cost)

# %%
encoder_history = encoderModel.fit(x_train,np.ones((y_train.shape)), epochs=50, batch_size=25, validation_split=0.25, callbacks=[EarlyStopping, LearningRateScheduler])
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 encoder_history = encoderModel.fit(x_train,np.ones((y_train.shape)), epochs=50, batch_size=25, validation_split=0.25, callbacks=[EarlyStopping, LearningRateScheduler])
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1650, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1642 with tf.profiler.experimental.Trace(
#    1643     "train",
#    1644     epoch_num=epoch,
#    (...)
#    1647     _r=1,
#    1648 ):
#    1649     callbacks.on_train_batch_begin(step)
# -> 1650     tmp_logs = self.train_function(iterator)
#    1651     if data_handler.should_sync:
#    1652         context.async_wait()
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1249, in Model.make_train_function.<locals>.train_function(iterator)
#    1247 def train_function(iterator):
#    1248     """Runs a training execution with a single step."""
# -> 1249     return step_function(self, iterator)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1233, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1229     run_step = tf.function(
#    1230         run_step, jit_compile=True, reduce_retracing=True
#    1231     )
#    1232 data = next(iterator)
# -> 1233 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1234 outputs = reduce_per_replica(
#    1235     outputs,
#    1236     self.distribute_strategy,
#    1237     reduction=self.distribute_reduction_method,
#    1238 )
#    1239 return outputs
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1316, in StrategyBase.run(***failed resolving arguments***)
#    1311 with self.scope():
#    1312   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1313   # applied when the caller is also in Eager mode.
#    1314   fn = autograph.tf_convert(
#    1315       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1316   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2895, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2893   kwargs = {}
#    2894 with self._container_strategy().scope():
# -> 2895   return self._call_for_each_replica(fn, args, kwargs)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3696, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3694 def _call_for_each_replica(self, fn, args, kwargs):
#    3695   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3696     return fn(*args, **kwargs)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\autograph\impl\api.py:595, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     593 def wrapper(*args, **kwargs):
#     594   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595     return func(*args, **kwargs)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1222, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#    1221 def run_step(data):
# -> 1222     outputs = model.train_step(data)
#    1223     # Ensure counter is updated only if `train_step` succeeds.
#    1224     with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1027, in Model.train_step(self, data)
#    1025 self._validate_target_and_loss(y, loss)
#    1026 # Run backwards pass.
# -> 1027 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#    1028 return self.compute_metrics(x, y, y_pred, sample_weight)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:526, in _BaseOptimizer.minimize(self, loss, var_list, tape)
#     505 def minimize(self, loss, var_list, tape=None):
#     506     """Minimize `loss` by updating `var_list`.
#     507
#     508     This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     524       None
#     525     """
# --> 526     grads_and_vars = self.compute_gradients(loss, var_list, tape)
#     527     self.apply_gradients(grads_and_vars)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:259, in _BaseOptimizer.compute_gradients(self, loss, var_list, tape)
#     256         if callable(var_list):
#     257             var_list = var_list()
# --> 259 grads = tape.gradient(loss, var_list)
#     260 return list(zip(grads, var_list))
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\backprop.py:1112, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1106   output_gradients = (
#    1107       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1108           output_gradients))
#    1109   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1110                       for x in output_gradients]
# -> 1112 flat_grad = imperative_grad.imperative_grad(
#    1113     self._tape,
#    1114     flat_targets,
#    1115     flat_sources,
#    1116     output_gradients=output_gradients,
#    1117     sources_raw=flat_sources_raw,
#    1118     unconnected_gradients=unconnected_gradients)
#    1120 if not self._persistent:
#    1121   # Keep track of watched variables before setting tape to None
#    1122   self._watched_variables = self._tape.watched_variables()
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\custom_gradient.py:586, in _eager_mode_decorator.<locals>.actual_grad_fn(*result_grad_components)
#     583     raise ValueError("Must return gradient for each variable from "
#     584                      "@custom_gradient grad_fn.")
#     585 else:
# --> 586   input_grads = grad_fn(*result_grads)
#     587   variable_grads = []
#     588 flat_grads = composite_tensor_gradient.get_flat_tensors_for_gradients(
#     589     nest.flatten(input_grads))
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\pennylane\interfaces\tensorflow.py:240, in execute.<locals>._execute.<locals>.grad_fn(*dy, **tfkwargs)
#     231     with qml.tape.Unwrap(*tapes, params=params_unwrapped):
#     232         vjp_tapes, processing_fn = qml.gradients.batch_vjp(
#     233             tapes,
#     234             dy,
#    (...)
#     237             gradient_kwargs=gradient_kwargs,
#     238         )
# --> 240         vjps = processing_fn(execute_fn(vjp_tapes)[0])
#     242 else:
#     243     vjp_tapes, processing_fn = qml.gradients.batch_vjp(
#     244         tapes,
#     245         dy,
#    (...)
#     248         gradient_kwargs=gradient_kwargs,
#     249     )
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\pennylane\interfaces\execution.py:205, in cache_execute.<locals>.wrapper(tapes, **kwargs)
#     201         return (res, []) if return_tuple else res
#     203 else:
#     204     # execute all unique tapes that do not exist in the cache
# --> 205     res = fn(execution_tapes.values(), **kwargs)
#     207 final_res = []
#     209 for i, tape in enumerate(tapes):
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\pennylane\interfaces\execution.py:131, in cache_execute.<locals>.fn(tapes, **kwargs)
#     129 def fn(tapes: Sequence[QuantumTape], **kwargs):  # pylint: disable=function-redefined
#     130     tapes = [expand_fn(tape) for tape in tapes]
# --> 131     return original_fn(tapes, **kwargs)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\pennylane_qiskit\ibmq.py:77, in IBMQDevice.batch_execute(self, circuits)
#      76 def batch_execute(self, circuits):  # pragma: no cover
# ---> 77     res = super().batch_execute(circuits)
#      78     if self.tracker.active:
#      79         self._track_run()
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\pennylane_qiskit\qiskit_device.py:458, in QiskitDevice.batch_execute(self, circuits)
#     455 def batch_execute(self, circuits):
#     456     # pylint: disable=missing-function-docstring
# --> 458     compiled_circuits = self.compile_circuits(circuits)
#     460     # Send the batch of circuit objects using backend.run
#     461     self._current_job = self.backend.run(compiled_circuits, shots=self.shots, **self.run_args)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\pennylane_qiskit\qiskit_device.py:449, in QiskitDevice.compile_circuits(self, circuits)
#     446 self.reset()
#     447 self.create_circuit_object(circuit.operations, rotations=circuit.diagonalizing_gates)
# --> 449 compiled_circ = self.compile()
#     450 compiled_circ.name = f"circ{len(compiled_circuits)}"
#     451 compiled_circuits.append(compiled_circ)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\pennylane_qiskit\qiskit_device.py:359, in QiskitDevice.compile(self)
#     353 """Compile the quantum circuit to target the provided compile_backend.
#     354
#     355 If compile_backend is None, then the target is simply the
#     356 backend.
#     357 """
#     358 compile_backend = self.compile_backend or self.backend
# --> 359 compiled_circuits = transpile(self._circuit, backend=compile_backend, **self.transpile_args)
#     360 return compiled_circuits
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit\compiler\transpiler.py:326, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods)
#     314 if (
#     315     scheduling_method is not None
#     316     and backend is None
#     317     and target is None
#     318     and not instruction_durations
#     319 ):
#     320     warnings.warn(
#     321         "When scheduling circuits without backend,"
#     322         " 'instruction_durations' should be usually provided.",
#     323         UserWarning,
#     324     )
# --> 326 unique_transpile_args, shared_args = _parse_transpile_args(
#     327     circuits,
#     328     backend,
#     329     basis_gates,
#     330     inst_map,
#     331     coupling_map,
#     332     backend_properties,
#     333     initial_layout,
#     334     layout_method,
#     335     routing_method,
#     336     translation_method,
#     337     scheduling_method,
#     338     instruction_durations,
#     339     dt,
#     340     approximation_degree,
#     341     seed_transpiler,
#     342     optimization_level,
#     343     callback,
#     344     output_name,
#     345     timing_constraints,
#     346     unitary_synthesis_method,
#     347     unitary_synthesis_plugin_config,
#     348     target,
#     349     hls_config,
#     350     init_method,
#     351     optimization_method,
#     352     ignore_backend_supplied_default_methods,
#     353 )
#     354 # Get transpile_args to configure the circuit transpilation job(s)
#     355 if coupling_map in unique_transpile_args:
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit\compiler\transpiler.py:651, in _parse_transpile_args(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, seed_transpiler, optimization_level, callback, output_name, timing_constraints, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods)
#     649 basis_gates = _parse_basis_gates(basis_gates, backend)
#     650 initial_layout = _parse_initial_layout(initial_layout, circuits)
# --> 651 inst_map = _parse_inst_map(inst_map, backend)
#     652 faulty_qubits_map = _parse_faulty_qubits_map(backend, num_circuits)
#     653 coupling_map = _parse_coupling_map(coupling_map, backend)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit\compiler\transpiler.py:812, in _parse_inst_map(inst_map, backend)
#     810 if backend_version <= 1:
#     811     if hasattr(backend, "defaults"):
# --> 812         inst_map = getattr(backend.defaults(), "instruction_schedule_map", None)
#     813 else:
#     814     inst_map = backend.target.instruction_schedule_map()
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit\providers\ibmq\ibmqbackend.py:507, in IBMQBackend.defaults(self, refresh)
#     493 """Return the pulse defaults for the backend.
#     494
#     495 The schema for default pulse configuration can be found in
#    (...)
#     504     The backend pulse defaults or ``None`` if the backend does not support pulse.
#     505 """
#     506 if refresh or self._defaults is None:
# --> 507     api_defaults = self._api_client.backend_pulse_defaults(self.name())
#     508     if api_defaults:
#     509         decode_pulse_defaults(api_defaults)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit\providers\ibmq\api\clients\account.py:111, in AccountClient.backend_pulse_defaults(self, backend_name)
#     102 def backend_pulse_defaults(self, backend_name: str) -> Dict:
#     103     """Return the pulse defaults of the backend.
#     104
#     105     Args:
#    (...)
#     109         Backend pulse defaults.
#     110     """
# --> 111     return self.account_api.backend(backend_name).pulse_defaults()
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit\providers\ibmq\api\rest\backend.py:83, in Backend.pulse_defaults(self)
#      77 """Return backend pulse defaults.
#      78
#      79 Returns:
#      80     JSON response of pulse defaults.
#      81 """
#      82 url = self.get_url('pulse_defaults')
# ---> 83 return self.session.get(url).json()
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit\providers\ibmq\api\session.py:277, in RetrySession.request(self, method, url, bare, **kwargs)
#     275 try:
#     276     self._log_request_info(url, method, kwargs)
# --> 277     response = super().request(method, final_url, headers=headers, **kwargs)
#     278     response.raise_for_status()
#     279 except RequestException as ex:
#     280     # Wrap the requests exceptions into a IBM Q custom one, for
#     281     # compatibility.
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\Samuel\AppData\Local\Programs\Python\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
encoderModel.summary()
encoderModel.save("archive/encoderModelClean-"+tag+".h5")
encoderModel.save_weights("archive/encoderWeightsClean-"+tag+".h5")
config = encoderModel.get_config()
np.save("archive/encoderConfigClean-"+tag+".npy", config)
fig = plt.figure()
plt.plot(encoder_history.history['loss'], lw=4, label='loss')
plt.plot(encoder_history.history['val_loss'], lw=4, label='val_loss')
plt.plot(encoder_history.history['lr'], lw=4, label='lr')
plt.xlabel("epoch", fontsize=16)
plt.legend(fontsize=14)
plt.show()
fig.savefig("archive/historyENC-"+tag+".png")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5)]               0
#
#  keras_layer (KerasLayer)    (None, 5)                 22
#
# =================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoded_train = encoderModel.predict(x_train)
encoded_train = encoded_train[:,:3]
np.save("data/ENCdata_"+tag+".npy", encoded_train)
print(encoded_train.shape)
# Out:
# 32/32 [==============================] - 55s 2s/step
# (1007, 3)

# %%
from pennylane import numpy as np
n_qubits = x_train.shape[1]
compression = 3

dev = qml.device("default.qubit", wires=n_qubits)

# %%
# Decoder
DEC_weight_shapes = {"weight1": (n_qubits),
                 "weight2": (n_qubits-1),
                 "weight3": (n_qubits-1),
                 "weight4": (n_qubits-1),
                 "weight5": (n_qubits)}
nD_qcParams = n_qubits*2+3*(n_qubits-1)
print(f"Params in the quantum layer to train: {nD_qcParams}")



@qml.qnode(dev)
def decoder(inputs, weight1, weight2, weight3, weight4, weight5):
    qml.broadcast(qml.RY, wires=range(compression), parameters=inputs, pattern="single")
    
    qml.broadcast(qml.RY, wires=range(n_qubits), parameters=weight1, pattern="single")
    qml.broadcast(qml.CRY, wires=range(n_qubits), parameters=weight2, pattern="chain")
    qml.broadcast(qml.CRY, wires=range(n_qubits), parameters=weight3, pattern="chain")
    qml.broadcast(qml.CRY, wires=range(n_qubits), parameters=weight4, pattern="chain")
    qml.broadcast(qml.RY, wires=range(n_qubits), parameters=weight5, pattern="single")
    
    return [qml.expval(qml.PauliZ(wires=i)) for i in range(n_qubits)]

qDecoder = qml.qnn.KerasLayer(decoder, DEC_weight_shapes, output_dim=n_qubits)

# Visualize the quantum circuit
print(qml.draw(decoder)(x_train[0,:3],np.random.rand(n_qubits), np.random.rand(n_qubits-1), np.random.rand(n_qubits-1), np.random.rand(n_qubits-1), np.random.rand(n_qubits)))
fig2, ax = qml.draw_mpl(decoder)(x_train[0,:3],np.random.rand(n_qubits), np.random.rand(n_qubits-1), np.random.rand(n_qubits-1), np.random.rand(n_qubits-1), np.random.rand(n_qubits))
plt.show()
fig2.savefig("archive/Decoder-"+tag+".png")
fig2.savefig("archive/Decoder-"+tag+".pdf")
# Out:
# Params in the quantum layer to train: 22
# 0: ──RY(0.02)──RY(0.80)─╭●──────────────────╭●──────────────────╭●─────────RY(0.24)──────────
# 1: ──RY(0.50)──RY(0.87)─╰RY(0.44)─╭●────────╰RY(0.94)─╭●────────╰RY(0.15)─╭●─────────RY(0.69)
# 2: ──RY(0.09)──RY(0.47)───────────╰RY(0.38)─╭●────────╰RY(0.45)─╭●────────╰RY(0.38)─╭●───────
# 3: ──RY(0.53)───────────────────────────────╰RY(0.02)─╭●────────╰RY(0.28)─╭●────────╰RY(0.42)
# 4: ──RY(0.46)─────────────────────────────────────────╰RY(0.79)───────────╰RY(0.07)──────────
#
# ──────────────────────┤  <Z>
# ──────────────────────┤  <Z>
# ───RY(0.97)───────────┤  <Z>
# ──╭●─────────RY(0.40)─┤  <Z>
# ──╰RY(0.67)──RY(0.39)─┤  <Z>

# %%
#Training
#['mean_squared_error', 'mean_absolute_error','mean_squared_logarithmic_error', 'mean_absolute_percentage_error']

inputLayer = Input(shape=(encoded_train.shape[1],))
decoded = qDecoder(inputLayer)
# Decoder
decoderModel = Model(inputLayer, decoded)
def scheduler(epoch, lr):
    if epoch < 8:
        return lr
    else:
        return lr* tf.math.exp(-0.1)
LearningRateScheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)
EarlyStopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="auto", min_delta=0.001, patience=20)

optRMS = tf.keras.optimizers.RMSprop(learning_rate=0.05)

decoderModel.compile(optimizer = optRMS, loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
print(encoded_train.shape)
# Out:
# (1007, 3)

# %%
decoder_history = decoderModel.fit(encoded_train, x_train, epochs=50, batch_size=25, validation_split=0.25, callbacks=[EarlyStopping, LearningRateScheduler])
# Out:
# Epoch 1/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.1196 - mean_absolute_error: 0.2809 - val_loss: 0.1098 - val_mean_absolute_error: 0.2757 - lr: 0.0500
# Epoch 2/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0932 - mean_absolute_error: 0.2490 - val_loss: 0.0943 - val_mean_absolute_error: 0.2284 - lr: 0.0500
# Epoch 3/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0841 - mean_absolute_error: 0.2315 - val_loss: 0.0950 - val_mean_absolute_error: 0.2262 - lr: 0.0500
# Epoch 4/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0774 - mean_absolute_error: 0.2191 - val_loss: 0.0835 - val_mean_absolute_error: 0.2161 - lr: 0.0500
# Epoch 5/50
# 31/31 [==============================] - 95s 3s/step - loss: 0.0709 - mean_absolute_error: 0.2046 - val_loss: 0.0746 - val_mean_absolute_error: 0.1959 - lr: 0.0500
# Epoch 6/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0678 - mean_absolute_error: 0.1960 - val_loss: 0.0778 - val_mean_absolute_error: 0.2124 - lr: 0.0500
# Epoch 7/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0665 - mean_absolute_error: 0.1930 - val_loss: 0.0663 - val_mean_absolute_error: 0.2006 - lr: 0.0500
# Epoch 8/50
# 31/31 [==============================] - 100s 3s/step - loss: 0.0663 - mean_absolute_error: 0.1935 - val_loss: 0.0660 - val_mean_absolute_error: 0.1829 - lr: 0.0500
# Epoch 9/50
# 31/31 [==============================] - 95s 3s/step - loss: 0.0666 - mean_absolute_error: 0.1930 - val_loss: 0.0747 - val_mean_absolute_error: 0.1979 - lr: 0.0452
# Epoch 10/50
# 31/31 [==============================] - 92s 3s/step - loss: 0.0650 - mean_absolute_error: 0.1907 - val_loss: 0.0630 - val_mean_absolute_error: 0.1908 - lr: 0.0409
# Epoch 11/50
# 31/31 [==============================] - 92s 3s/step - loss: 0.0645 - mean_absolute_error: 0.1887 - val_loss: 0.0686 - val_mean_absolute_error: 0.1883 - lr: 0.0370
# Epoch 12/50
# 31/31 [==============================] - 96s 3s/step - loss: 0.0644 - mean_absolute_error: 0.1888 - val_loss: 0.0647 - val_mean_absolute_error: 0.1960 - lr: 0.0335
# Epoch 13/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0635 - mean_absolute_error: 0.1863 - val_loss: 0.0676 - val_mean_absolute_error: 0.1804 - lr: 0.0303
# Epoch 14/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0625 - mean_absolute_error: 0.1842 - val_loss: 0.0602 - val_mean_absolute_error: 0.1832 - lr: 0.0274
# Epoch 15/50
# 31/31 [==============================] - 95s 3s/step - loss: 0.0610 - mean_absolute_error: 0.1811 - val_loss: 0.0611 - val_mean_absolute_error: 0.1831 - lr: 0.0248
# Epoch 16/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0605 - mean_absolute_error: 0.1785 - val_loss: 0.0583 - val_mean_absolute_error: 0.1698 - lr: 0.0225
# Epoch 17/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0597 - mean_absolute_error: 0.1776 - val_loss: 0.0571 - val_mean_absolute_error: 0.1703 - lr: 0.0203
# Epoch 18/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0595 - mean_absolute_error: 0.1764 - val_loss: 0.0561 - val_mean_absolute_error: 0.1723 - lr: 0.0184
# Epoch 19/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0592 - mean_absolute_error: 0.1748 - val_loss: 0.0560 - val_mean_absolute_error: 0.1742 - lr: 0.0166
# Epoch 20/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0587 - mean_absolute_error: 0.1739 - val_loss: 0.0598 - val_mean_absolute_error: 0.1754 - lr: 0.0151
# Epoch 21/50
# 31/31 [==============================] - 93s 3s/step - loss: 0.0590 - mean_absolute_error: 0.1743 - val_loss: 0.0560 - val_mean_absolute_error: 0.1766 - lr: 0.0136
# Epoch 22/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0586 - mean_absolute_error: 0.1736 - val_loss: 0.0554 - val_mean_absolute_error: 0.1640 - lr: 0.0123
# Epoch 23/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0584 - mean_absolute_error: 0.1722 - val_loss: 0.0551 - val_mean_absolute_error: 0.1655 - lr: 0.0112
# Epoch 24/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0583 - mean_absolute_error: 0.1722 - val_loss: 0.0549 - val_mean_absolute_error: 0.1698 - lr: 0.0101
# Epoch 25/50
# 31/31 [==============================] - 95s 3s/step - loss: 0.0582 - mean_absolute_error: 0.1718 - val_loss: 0.0551 - val_mean_absolute_error: 0.1700 - lr: 0.0091
# Epoch 26/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0580 - mean_absolute_error: 0.1720 - val_loss: 0.0549 - val_mean_absolute_error: 0.1668 - lr: 0.0083
# Epoch 27/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0579 - mean_absolute_error: 0.1713 - val_loss: 0.0558 - val_mean_absolute_error: 0.1634 - lr: 0.0075
# Epoch 28/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0579 - mean_absolute_error: 0.1712 - val_loss: 0.0547 - val_mean_absolute_error: 0.1651 - lr: 0.0068
# Epoch 29/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0578 - mean_absolute_error: 0.1706 - val_loss: 0.0550 - val_mean_absolute_error: 0.1711 - lr: 0.0061
# Epoch 30/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0578 - mean_absolute_error: 0.1716 - val_loss: 0.0550 - val_mean_absolute_error: 0.1751 - lr: 0.0055
# Epoch 31/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0578 - mean_absolute_error: 0.1715 - val_loss: 0.0545 - val_mean_absolute_error: 0.1674 - lr: 0.0050
# Epoch 32/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0576 - mean_absolute_error: 0.1707 - val_loss: 0.0546 - val_mean_absolute_error: 0.1696 - lr: 0.0045
# Epoch 33/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0576 - mean_absolute_error: 0.1713 - val_loss: 0.0548 - val_mean_absolute_error: 0.1629 - lr: 0.0041
# Epoch 34/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0576 - mean_absolute_error: 0.1700 - val_loss: 0.0548 - val_mean_absolute_error: 0.1645 - lr: 0.0037
# Epoch 35/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0576 - mean_absolute_error: 0.1700 - val_loss: 0.0546 - val_mean_absolute_error: 0.1666 - lr: 0.0034
# Epoch 36/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0575 - mean_absolute_error: 0.1706 - val_loss: 0.0545 - val_mean_absolute_error: 0.1675 - lr: 0.0030
# Epoch 37/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0575 - mean_absolute_error: 0.1706 - val_loss: 0.0545 - val_mean_absolute_error: 0.1660 - lr: 0.0028
# Epoch 38/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0574 - mean_absolute_error: 0.1704 - val_loss: 0.0545 - val_mean_absolute_error: 0.1640 - lr: 0.0025
# Epoch 39/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0575 - mean_absolute_error: 0.1695 - val_loss: 0.0544 - val_mean_absolute_error: 0.1661 - lr: 0.0023
# Epoch 40/50
# 31/31 [==============================] - 93s 3s/step - loss: 0.0574 - mean_absolute_error: 0.1705 - val_loss: 0.0545 - val_mean_absolute_error: 0.1641 - lr: 0.0020
# Epoch 41/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0574 - mean_absolute_error: 0.1697 - val_loss: 0.0544 - val_mean_absolute_error: 0.1651 - lr: 0.0018
# Epoch 42/50
# 31/31 [==============================] - 93s 3s/step - loss: 0.0574 - mean_absolute_error: 0.1700 - val_loss: 0.0544 - val_mean_absolute_error: 0.1659 - lr: 0.0017
# Epoch 43/50
# 31/31 [==============================] - 94s 3s/step - loss: 0.0574 - mean_absolute_error: 0.1701 - val_loss: 0.0544 - val_mean_absolute_error: 0.1654 - lr: 0.0015

# %%
import numpy as np

def plot_metrics(history):
    n = len(history.history.keys())//2
    fig,axs = plt.subplots(1,n, figsize=(18,5))

    for i,[key,val] in enumerate(history.history.items()):
        axs[i%n].plot(history.history[key], lw=4, label=key.replace("_", " "))
    
    for ax in axs:
        #ax.set_yscale("log")
        ax.set_xlabel("epoch", fontsize=16)
        ax.legend(fontsize=14)
plot_metrics(decoder_history)
decoderModel.summary()

fig = plt.figure()
plt.plot(decoder_history.history['loss'], lw=4, label='loss')
plt.plot(decoder_history.history['val_loss'], lw=4, label='val_loss')
plt.plot(decoder_history.history['lr'], lw=4, label='lr')
plt.xlabel("epoch", fontsize=16)
plt.legend(fontsize=14)
plt.show()
fig.savefig("archive/historyDEC-"+tag+".png")
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 3)]               0
#
#  keras_layer_1 (KerasLayer)  (None, 5)                 22
#
# =================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Create a autoencode like in https://blog.keras.io/building-autoencoders-in-keras.html
clear_session()

inputLayer = Input(shape=(x_train.shape[1],))
encoded = encoderModel(inputLayer)
encoded = encoded[:,:3]
decoded = decoderModel(encoded)
autoencoder = Model(inputLayer, decoded)
print(f"Params in all quantum layers to train: {nD_qcParams+nE_qcParams}")
autoencoder.summary()
# Out:
# Params in all quantum layers to train: 44
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5)]               0
#
#  model (Functional)          (None, 5)                 22
#
#  tf.__operators__.getitem (S  (None, 3)                0
#  licingOpLambda)
#
#  model_1 (Functional)        (None, 5)                 22
#
# =================================================================
# Total params: 44
# Trainable params: 44
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Training
#['mean_squared_error', 'mean_absolute_error','mean_squared_logarithmic_error', 'mean_absolute_percentage_error']

def scheduler(epoch, lr):
    if epoch < 8:
        return lr
    else:
        return lr* tf.math.exp(-0.1)
LearningRateScheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)
EarlyStopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="auto", min_delta=0.001, patience=20)

optRMS = tf.keras.optimizers.RMSprop(learning_rate=0.05)

autoencoder.compile(optimizer = optRMS, loss='mean_squared_error', metrics=['mean_absolute_error'])

autoencoder_history = autoencoder.fit(x_train[:334,:], x_train[:334,:], epochs=25, batch_size=25, validation_split=0.25, callbacks=[EarlyStopping, LearningRateScheduler])
# Out:
# Epoch 1/25
# 10/10 [==============================] - 68s 7s/step - loss: 0.0606 - mean_absolute_error: 0.1816 - val_loss: 0.0500 - val_mean_absolute_error: 0.1569 - lr: 0.0500
# Epoch 2/25
# 10/10 [==============================] - 67s 7s/step - loss: 0.0471 - mean_absolute_error: 0.1604 - val_loss: 0.0468 - val_mean_absolute_error: 0.1437 - lr: 0.0500
# Epoch 3/25
# 10/10 [==============================] - 67s 7s/step - loss: 0.0431 - mean_absolute_error: 0.1444 - val_loss: 0.0508 - val_mean_absolute_error: 0.1656 - lr: 0.0500
# Epoch 4/25
# 10/10 [==============================] - 68s 7s/step - loss: 0.0453 - mean_absolute_error: 0.1542 - val_loss: 0.0483 - val_mean_absolute_error: 0.1521 - lr: 0.0500
# Epoch 5/25
# 10/10 [==============================] - 68s 7s/step - loss: 0.0432 - mean_absolute_error: 0.1482 - val_loss: 0.0524 - val_mean_absolute_error: 0.1622 - lr: 0.0500
# Epoch 6/25
# 10/10 [==============================] - 68s 7s/step - loss: 0.0444 - mean_absolute_error: 0.1486 - val_loss: 0.0478 - val_mean_absolute_error: 0.1568 - lr: 0.0500
# Epoch 7/25
# 10/10 [==============================] - 68s 7s/step - loss: 0.0417 - mean_absolute_error: 0.1427 - val_loss: 0.0472 - val_mean_absolute_error: 0.1442 - lr: 0.0500
# Epoch 8/25
# 10/10 [==============================] - 68s 7s/step - loss: 0.0459 - mean_absolute_error: 0.1543 - val_loss: 0.0473 - val_mean_absolute_error: 0.1488 - lr: 0.0500
# Epoch 9/25
# 10/10 [==============================] - 68s 7s/step - loss: 0.0415 - mean_absolute_error: 0.1416 - val_loss: 0.0445 - val_mean_absolute_error: 0.1358 - lr: 0.0452
# Epoch 10/25
# 10/10 [==============================] - 67s 7s/step - loss: 0.0400 - mean_absolute_error: 0.1347 - val_loss: 0.0491 - val_mean_absolute_error: 0.1560 - lr: 0.0409
# Epoch 11/25
# 10/10 [==============================] - 68s 7s/step - loss: 0.0410 - mean_absolute_error: 0.1353 - val_loss: 0.0445 - val_mean_absolute_error: 0.1329 - lr: 0.0370
# Epoch 12/25
# 10/10 [==============================] - 67s 7s/step - loss: 0.0383 - mean_absolute_error: 0.1277 - val_loss: 0.0457 - val_mean_absolute_error: 0.1372 - lr: 0.0335
# Epoch 13/25
# 10/10 [==============================] - 68s 7s/step - loss: 0.0375 - mean_absolute_error: 0.1238 - val_loss: 0.0469 - val_mean_absolute_error: 0.1488 - lr: 0.0303
# Epoch 14/25
# 10/10 [==============================] - 68s 7s/step - loss: 0.0370 - mean_absolute_error: 0.1197 - val_loss: 0.0436 - val_mean_absolute_error: 0.1263 - lr: 0.0274
# Epoch 15/25
# 10/10 [==============================] - 68s 7s/step - loss: 0.0373 - mean_absolute_error: 0.1225 - val_loss: 0.0462 - val_mean_absolute_error: 0.1423 - lr: 0.0248
# Epoch 16/25
# 10/10 [==============================] - 67s 7s/step - loss: 0.0371 - mean_absolute_error: 0.1187 - val_loss: 0.0430 - val_mean_absolute_error: 0.1228 - lr: 0.0225
# Epoch 17/25
# 10/10 [==============================] - 67s 7s/step - loss: 0.0378 - mean_absolute_error: 0.1219 - val_loss: 0.0430 - val_mean_absolute_error: 0.1204 - lr: 0.0203
# Epoch 18/25
# 10/10 [==============================] - 67s 7s/step - loss: 0.0360 - mean_absolute_error: 0.1119 - val_loss: 0.0435 - val_mean_absolute_error: 0.1289 - lr: 0.0184
# Epoch 19/25
# 10/10 [==============================] - 68s 7s/step - loss: 0.0361 - mean_absolute_error: 0.1149 - val_loss: 0.0434 - val_mean_absolute_error: 0.1256 - lr: 0.0166
# Epoch 20/25
# 10/10 [==============================] - 67s 7s/step - loss: 0.0361 - mean_absolute_error: 0.1134 - val_loss: 0.0439 - val_mean_absolute_error: 0.1312 - lr: 0.0151
# Epoch 21/25
# 10/10 [==============================] - 68s 7s/step - loss: 0.0361 - mean_absolute_error: 0.1163 - val_loss: 0.0442 - val_mean_absolute_error: 0.1299 - lr: 0.0136
# Epoch 22/25
# 10/10 [==============================] - 68s 7s/step - loss: 0.0359 - mean_absolute_error: 0.1121 - val_loss: 0.0429 - val_mean_absolute_error: 0.1237 - lr: 0.0123
# Epoch 23/25
# 10/10 [==============================] - 67s 7s/step - loss: 0.0358 - mean_absolute_error: 0.1117 - val_loss: 0.0431 - val_mean_absolute_error: 0.1217 - lr: 0.0112
# Epoch 24/25
# 10/10 [==============================] - 67s 7s/step - loss: 0.0359 - mean_absolute_error: 0.1113 - val_loss: 0.0428 - val_mean_absolute_error: 0.1206 - lr: 0.0101
# Epoch 25/25
# 10/10 [==============================] - 67s 7s/step - loss: 0.0356 - mean_absolute_error: 0.1094 - val_loss: 0.0440 - val_mean_absolute_error: 0.1307 - lr: 0.0091

# %%
import numpy as np

def plot_metrics(history):
    n = len(history.history.keys())//2
    fig,axs = plt.subplots(1,n, figsize=(18,5))

    for i,[key,val] in enumerate(history.history.items()):
        axs[i%n].plot(history.history[key], lw=4, label=key.replace("_", " "))
    
    for ax in axs:
        #ax.set_yscale("log")
        ax.set_xlabel("epoch", fontsize=16)
        ax.legend(fontsize=14)
plot_metrics(autoencoder_history)

# %%
fig = plt.figure()
plt.plot(autoencoder_history.history['loss'], lw=4, label='loss')
plt.plot(autoencoder_history.history['val_loss'], lw=4, label='val_loss')
plt.plot(autoencoder_history.history['lr'], lw=4, label='lr')
plt.xlabel("epoch", fontsize=16)
plt.legend(fontsize=14)
plt.show()
fig.savefig("archive/history-"+tag+".png")

# %%
evaluation = autoencoder.evaluate(x_test[:-1], x_test[:-1])
encoded_test = encoderModel.predict(x_test)
decoded_test = decoderModel.predict(encoded_test[:,:3])
print(f'Data: {x_test[0,:]} to be: {encoded_test[0,:]} and rebuilded it to: {decoded_test[0,:]}')
# Out:
# 16/16 [==============================] - 50s 3s/step - loss: 0.0393 - mean_absolute_error: 0.1230
# 16/16 [==============================] - 27s 2s/step
# 16/16 [==============================] - 23s 1s/step
# Data: [0.01010101 0.         1.         0.         0.05019733] to be: [ 0.16158454 -0.11439376 -0.42796803  0.91604852] and rebuilded it to: [0.04924981 0.04151099 0.87886601 0.50965951 0.04225659]

# %%
encoderModel.save("archive/encoderModel-"+tag+".h5")
encoderModel.save_weights("archive/encoderWeights-"+tag+".h5")
decoderModel.save("archive/encoderModel-"+tag+".h5")
decoderModel.save_weights("archive/decoderWeights-"+tag+".h5")
autoencoder.save("archive/completeModel-"+tag+".h5")
autoencoder.save_weights("archive/autoencoderWeights-"+tag+".h5")
config = encoderModel.get_config()
np.save("archive/encoderConfig-"+tag+".npy", config)
config = decoderModel.get_config()
np.save("archive/decoderConfig-"+tag+".npy", config)
config = autoencoder.get_config()
np.save("archive/completeConfig-"+tag+".npy", config)
